# %%
import pandas as pd

# %%
df = pd.read_csv('bronze/Properties.csv', encoding='utf-8', sep=';')
df
# Out:
#                                            property_url  \
# 0     https://www.pedrogranado.com.br/comprar/maring...
# 1     https://www.pedrogranado.com.br/comprar/maring...
# 2     https://www.pedrogranado.com.br/comprar/maring...
# 3     https://www.pedrogranado.com.br/comprar/maring...
# 4     https://www.pedrogranado.com.br/comprar/maring...
# ...                                                 ...
# 2788  https://www.silvioiwata.com.br/imovel/36200066...
# 2789  https://www.silvioiwata.com.br/imovel/36200066...
# 2790  https://www.silvioiwata.com.br/imovel/36200066...
# 2791  https://www.silvioiwata.com.br/imovel/36200066...
# 2792  https://www.silvioiwata.com.br/imovel/36200066...
#
#                      broker              district          price    type  \
# 0     Pedro Granado Imóveis               Zona 08   Consulte-nos  Padrão
# 1     Pedro Granado Imóveis               Zona 01   R$ 90.000,00  Padrão
# 2     Pedro Granado Imóveis               Zona 01  R$ 126.312,10  Padrão
# 3     Pedro Granado Imóveis      Jardim Barcelona  R$ 135.000,00  Padrão
# 4     Pedro Granado Imóveis  Jardim Novo Paulista  R$ 140.000,00  Padrão
# ...                     ...                   ...            ...     ...
# 2788           Silvio Iwata        Zona 01 Centro  R$ 400.000,00     NaN
# 2789           Silvio Iwata     Loteamento Malbec  R$ 425.000,00     NaN
# 2790           Silvio Iwata                   NaN  R$ 650.000,00     NaN
# 2791           Silvio Iwata                   NaN  R$ 720.000,00     NaN
# 2792           Silvio Iwata                   NaN  R$ 980.000,00     NaN
#
#          city state      ref               category       area        lat  \
# 0     Maringa    PR   5363.0            Apartamento   55,34 m² -23.446941
# 1     Maringá    PR  31223.0            Apartamento   48,40 m² -23.421000
# 2     Maringá    PR  35423.0            Apartamento   66,36 m² -23.421000
# 3     Maringá    PR  82763.0                Terreno  300,00 m² -23.459239
# 4     Maringá    PR  48803.0                Terreno  200,00 m² -23.408781
# ...       ...   ...      ...                    ...        ...        ...
# 2788  Maringá    PR      NaN  Sala Comercial (Loja)   38,14 m² -23.419317
# 2789  Maringá    PR      NaN            Apartamento   50,27 m² -23.439086
# 2790  Maringá    PR      NaN                   Casa  195,00 m² -23.414371
# 2791  Maringá    PR      NaN                   Casa  117,00 m² -23.469303
# 2792  Maringá    PR      NaN                Sobrado  297,11 m² -23.412047
#
#            long num_bedroom num_bathroom num_garage  added_date   sold_date
# 0    -51.919694           2            1          -  2025-04-15  2025-09-09
# 1    -51.933056           1            1          -  2025-04-15         NaN
# 2    -51.933056           1            1          -  2025-04-15         NaN
# 3    -51.981950           -            -          -  2025-04-15         NaN
# 4    -51.865269           -            -          -  2025-04-15         NaN
# ...         ...         ...          ...        ...         ...         ...
# 2788 -51.932306           2          NaN        NaN  2025-09-09         NaN
# 2789 -51.923115         2.0            2          2  2025-09-09         NaN
# 2790 -51.895299         3.0            3          2  2025-09-09         NaN
# 2791 -51.911690         3.0            2          2  2025-09-09         NaN
# 2792 -51.926968         3.0            3          3  2025-09-09         NaN
#
# [2793 rows x 17 columns]

# %%
df['district'] = df['district'].str.title()
df['price'] = pd.to_numeric(df['price'].str.replace('R$ ', '').str.replace('.', '').str.replace(',', '.'), errors='coerce')
df['type'] = df['type'].str.title()
df['city'] = df['city'].str.title().str.replace('Maringa', 'Maringá')
df['state'] = df['state'].str.upper()
df['ref'] =  df['ref'].astype(str).str.strip()
df['category'] = df['category'].str.title()
df['area'] = pd.to_numeric(df['area'].str.replace('m²', '').str.replace('.', '').str.replace(',', '.').str.strip(), errors='coerce')
df['lat'] = pd.to_numeric(df['lat'], errors='coerce')
df['long'] = pd.to_numeric(df['long'], errors='coerce')
df['num_bedroom'] = pd.to_numeric(df['num_bedroom'], errors='coerce')
df['num_bathroom'] = pd.to_numeric(df['num_bathroom'], errors='coerce')
df['num_garage'] = pd.to_numeric(df['num_garage'], errors='coerce')
df['added_date'] = pd.to_datetime(df['added_date'], errors='coerce').dt.date
df['sold_date'] = pd.to_datetime(df['sold_date'], errors='coerce').dt.date

# %%
map = {
    'Apartamento': 'Apartamento',
    'Apto': 'Apartamento',
    'Apartamento Kitnet': 'Apartamento',
    'Apartamento Duplex': 'Apartamento',
    'Casa': 'Casa',
    'Casa/Sobrado': 'Casa',
    'Casa Em Condomínio': 'Casa',
    'Sobrado': 'Casa',
    'Sobrado Em Condomínio': 'Casa',
    'Prédio': 'Apartamento',
    'Predio': 'Apartamento',
    'Comercial': 'Comercial',
    'Sala Comercial': 'Comercial',
    'Sala Comercial Em Edifício': 'Comercial',
    'Salão Comercial': 'Comercial',
    'Salão': 'Comercial',
    'Barracão': 'Galpão',
    'Galpão': 'Galpão',
    'Terreno': 'Terreno',
    'Terreno Em Condomínio': 'Terreno',
    'Terreno Comercial': 'Terreno',
    'Chácara': 'Fazenda',
    'Chácara Em Área De Lazer': 'Fazenda',
    'Fazenda': 'Fazenda',
    'Sítio': 'Fazenda',
    'Sítios': 'Fazenda',
    'Rural': 'Fazenda',
    'Área': 'Casa',
    'Negócio': 'Comercial',
    'Imóvel A Beira De Rio E Lago': "Fazenda",
    'Sala': 'Comercial'
}

df['category'] = df['category'].replace(map)

# %%
df.loc[~pd.isna(df['sold_date']), 'is_sold'] = True
df.loc[pd.isna(df['sold_date']), 'is_sold'] = False

# %%
df['days_on_market'] = (pd.to_datetime(df['sold_date']) - pd.to_datetime(df['added_date'])).dt.days

# %%
df['price_per_m2'] = df['price'] / df['area']

# %%
df = df[pd.to_datetime(df['added_date']) >= pd.to_datetime('01-08-2025', format='%d-%m-%Y')].reset_index(drop=True)

# %%
df = df[df['city'] == 'Maringá']

# %%
df.drop(columns=['property_url', 'ref', 'city', 'state'], inplace=True)

# %%
df.dropna(subset=['district', 'price']).reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                     broker                                         district  \
# 0    Pedro Granado Imóveis  Conjunto Habitacional Inocente Vila Nova Júnior
# 1    Pedro Granado Imóveis                                   Vila Vardelina
# 2    Pedro Granado Imóveis                                  Jardim Brasilia
# 3    Pedro Granado Imóveis                            Jardim Novo Horizonte
# 4    Pedro Granado Imóveis                                          Zona 01
# ..                     ...                                              ...
# 301           Silvio Iwata                                   Zona 01 Centro
# 302           Silvio Iwata                                Loteamento Malbec
# 303           Silvio Iwata                                              NaN
# 304           Silvio Iwata                                              NaN
# 305           Silvio Iwata                                              NaN
#
#          price     type               category    area        lat       long  \
# 0     259000.0     Casa                   Casa  259.02        NaN        NaN
# 1     275000.0   Padrão            Apartamento   51.56        NaN        NaN
# 2     399000.0  Sobrado                   Casa  150.00        NaN        NaN
# 3          NaN   Padrão            Apartamento   68.73        NaN        NaN
# 4    1490000.0   Padrão            Apartamento  177.99        NaN        NaN
# ..         ...      ...                    ...     ...        ...        ...
# 301   400000.0      NaN  Sala Comercial (Loja)   38.14 -23.419317 -51.932306
# 302   425000.0      NaN            Apartamento   50.27 -23.439086 -51.923115
# 303   650000.0      NaN                   Casa  195.00 -23.414371 -51.895299
# 304   720000.0      NaN                   Casa  117.00 -23.469303 -51.911690
# 305   980000.0      NaN                   Casa  297.11 -23.412047 -51.926968
#
#      num_bedroom  num_bathroom  num_garage  added_date   sold_date is_sold  \
# 0            3.0           3.0         1.0  2025-08-01         NaT   False
# 1            2.0           1.0         NaN  2025-08-01         NaT   False
# 2            3.0           2.0         1.0  2025-08-01         NaT   False
# 3            3.0           2.0         1.0  2025-08-01  2025-09-09    True
# 4            3.0           4.0         3.0  2025-08-01         NaT   False
# ..           ...           ...         ...         ...         ...     ...
# 301          2.0           NaN         NaN  2025-09-09         NaT   False
# 302          2.0           2.0         2.0  2025-09-09         NaT   False
# 303          3.0           3.0         2.0  2025-09-09         NaT   False
# 304          3.0           2.0         2.0  2025-09-09         NaT   False
# 305          3.0           3.0         3.0  2025-09-09         NaT   False
#
#      days_on_market  price_per_m2
# 0               NaN    999.922786
# 1               NaN   5333.591932
# 2               NaN   2660.000000
# 3              39.0           NaN
# 4               NaN   8371.256812
# ..              ...           ...
# 301             NaN  10487.676980
# 302             NaN   8454.346529
# 303             NaN   3333.333333
# 304             NaN   6153.846154
# 305             NaN   3298.441655
#
# [291 rows x 16 columns]

# %%
df.to_csv('silver/Properties_silver.csv', index=False, sep=';')
