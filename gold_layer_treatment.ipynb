# %%
import pandas as pd
import geopandas as  gpd

# %%
df = pd.read_csv('silver/Properties_silver.csv', encoding='utf-8', sep=';')
df
# Out:
#                     broker                                         district  \
# 0    Pedro Granado Imóveis  Conjunto Habitacional Inocente Vila Nova Júnior
# 1    Pedro Granado Imóveis                                   Vila Vardelina
# 2    Pedro Granado Imóveis                                  Jardim Brasilia
# 3    Pedro Granado Imóveis                            Jardim Novo Horizonte
# 4    Pedro Granado Imóveis                                          Zona 01
# ..                     ...                                              ...
# 286           Silvio Iwata                                   Zona 01 Centro
# 287           Silvio Iwata                                Loteamento Malbec
# 288           Silvio Iwata                                              NaN
# 289           Silvio Iwata                                              NaN
# 290           Silvio Iwata                                              NaN
#
#          price     type               category    area        lat       long  \
# 0     259000.0     Casa                   Casa  259.02        NaN        NaN
# 1     275000.0   Padrão            Apartamento   51.56        NaN        NaN
# 2     399000.0  Sobrado                   Casa  150.00        NaN        NaN
# 3          NaN   Padrão            Apartamento   68.73        NaN        NaN
# 4    1490000.0   Padrão            Apartamento  177.99        NaN        NaN
# ..         ...      ...                    ...     ...        ...        ...
# 286   400000.0      NaN  Sala Comercial (Loja)   38.14 -23.419317 -51.932306
# 287   425000.0      NaN            Apartamento   50.27 -23.439086 -51.923115
# 288   650000.0      NaN                   Casa  195.00 -23.414371 -51.895299
# 289   720000.0      NaN                   Casa  117.00 -23.469303 -51.911690
# 290   980000.0      NaN                   Casa  297.11 -23.412047 -51.926968
#
#      num_bedroom  num_bathroom  num_garage  added_date   sold_date  is_sold  \
# 0            3.0           3.0         1.0  2025-08-01         NaN    False
# 1            2.0           1.0         NaN  2025-08-01         NaN    False
# 2            3.0           2.0         1.0  2025-08-01         NaN    False
# 3            3.0           2.0         1.0  2025-08-01  2025-09-09     True
# 4            3.0           4.0         3.0  2025-08-01         NaN    False
# ..           ...           ...         ...         ...         ...      ...
# 286          2.0           NaN         NaN  2025-09-09         NaN    False
# 287          2.0           2.0         2.0  2025-09-09         NaN    False
# 288          3.0           3.0         2.0  2025-09-09         NaN    False
# 289          3.0           2.0         2.0  2025-09-09         NaN    False
# 290          3.0           3.0         3.0  2025-09-09         NaN    False
#
#      days_on_market  price_per_m2
# 0               NaN    999.922786
# 1               NaN   5333.591932
# 2               NaN   2660.000000
# 3              39.0           NaN
# 4               NaN   8371.256812
# ..              ...           ...
# 286             NaN  10487.676980
# 287             NaN   8454.346529
# 288             NaN   3333.333333
# 289             NaN   6153.846154
# 290             NaN   3298.441655
#
# [291 rows x 16 columns]

# %%
df_geo = gpd.GeoDataFrame(
    df,
    geometry=gpd.points_from_xy(df['long'], df['lat']),
    crs="EPSG:4326"
)

gdf_districts = gpd.read_file("maringa_shape\maringa.shx")

gdf_districts = gdf_districts.to_crs("EPSG:4326")

df_districts_adjusted = gpd.sjoin(df_geo, gdf_districts[['NM_SUBDIST', 'geometry']], how="left", predicate="within")

# %%
df_districts_adjusted.drop(['index_right', 'geometry'], axis=1, inplace=True)

# %%
df_districts_adjusted.rename(columns={'district': 'subdistrict',
                                      'NM_SUBDIST': 'district'}, inplace=True)

# %%
len(df_districts_adjusted.columns)
# Out:
# 17

# %%
df_districts_adjusted
# Out:
#                     broker                                      subdistrict  \
# 0    Pedro Granado Imóveis  Conjunto Habitacional Inocente Vila Nova Júnior
# 1    Pedro Granado Imóveis                                   Vila Vardelina
# 2    Pedro Granado Imóveis                                  Jardim Brasilia
# 3    Pedro Granado Imóveis                            Jardim Novo Horizonte
# 4    Pedro Granado Imóveis                                          Zona 01
# ..                     ...                                              ...
# 286           Silvio Iwata                                   Zona 01 Centro
# 287           Silvio Iwata                                Loteamento Malbec
# 288           Silvio Iwata                                              NaN
# 289           Silvio Iwata                                              NaN
# 290           Silvio Iwata                                              NaN
#
#          price     type               category    area        lat       long  \
# 0     259000.0     Casa                   Casa  259.02        NaN        NaN
# 1     275000.0   Padrão            Apartamento   51.56        NaN        NaN
# 2     399000.0  Sobrado                   Casa  150.00        NaN        NaN
# 3          NaN   Padrão            Apartamento   68.73        NaN        NaN
# 4    1490000.0   Padrão            Apartamento  177.99        NaN        NaN
# ..         ...      ...                    ...     ...        ...        ...
# 286   400000.0      NaN  Sala Comercial (Loja)   38.14 -23.419317 -51.932306
# 287   425000.0      NaN            Apartamento   50.27 -23.439086 -51.923115
# 288   650000.0      NaN                   Casa  195.00 -23.414371 -51.895299
# 289   720000.0      NaN                   Casa  117.00 -23.469303 -51.911690
# 290   980000.0      NaN                   Casa  297.11 -23.412047 -51.926968
#
#      num_bedroom  num_bathroom  num_garage  added_date   sold_date  is_sold  \
# 0            3.0           3.0         1.0  2025-08-01         NaN    False
# 1            2.0           1.0         NaN  2025-08-01         NaN    False
# 2            3.0           2.0         1.0  2025-08-01         NaN    False
# 3            3.0           2.0         1.0  2025-08-01  2025-09-09     True
# 4            3.0           4.0         3.0  2025-08-01         NaN    False
# ..           ...           ...         ...         ...         ...      ...
# 286          2.0           NaN         NaN  2025-09-09         NaN    False
# 287          2.0           2.0         2.0  2025-09-09         NaN    False
# 288          3.0           3.0         2.0  2025-09-09         NaN    False
# 289          3.0           2.0         2.0  2025-09-09         NaN    False
# 290          3.0           3.0         3.0  2025-09-09         NaN    False
#
#      days_on_market  price_per_m2 district
# 0               NaN    999.922786      NaN
# 1               NaN   5333.591932      NaN
# 2               NaN   2660.000000      NaN
# 3              39.0           NaN      NaN
# 4               NaN   8371.256812      NaN
# ..              ...           ...      ...
# 286             NaN  10487.676980   Zona 9
# 287             NaN   8454.346529  Zona 27
# 288             NaN   3333.333333  Zona 36
# 289             NaN   6153.846154  Zona 25
# 290             NaN   3298.441655   Zona 7
#
# [291 rows x 17 columns]

# %%
df_districts_adjusted.to_csv('gold/Properties_gold.csv', index=False, sep=';')
