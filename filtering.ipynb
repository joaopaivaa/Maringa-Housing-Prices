# %%
import pandas as pd

# %%
df = pd.read_csv('silver/Properties_silver.csv', encoding='utf-8', sep=';')
df
# Out:
#                                            property_url  \
# 0     https://www.pedrogranado.com.br/comprar/maring...
# 1     https://www.pedrogranado.com.br/comprar/maring...
# 2     https://www.pedrogranado.com.br/comprar/maring...
# 3     https://www.pedrogranado.com.br/comprar/maring...
# 4     https://www.pedrogranado.com.br/comprar/maring...
# ...                                                 ...
# 2549  https://www.pedrogranado.com.br/comprar/maring...
# 2550  https://www.leloimoveis.com.br/imovel/apartame...
# 2551  https://www.leloimoveis.com.br/imovel/sobrado-...
# 2552  https://www.silvioiwata.com.br/imovel/36200064...
# 2553  https://www.silvioiwata.com.br/imovel/36200064...
#
#                      broker                    district      price    type  \
# 0     Pedro Granado Imóveis                     Zona 08        NaN  Padrão
# 1     Pedro Granado Imóveis                     Zona 01    90000.0  Padrão
# 2     Pedro Granado Imóveis                     Zona 01   126312.1  Padrão
# 3     Pedro Granado Imóveis            Jardim Barcelona   135000.0  Padrão
# 4     Pedro Granado Imóveis        Jardim Novo Paulista   140000.0  Padrão
# ...                     ...                         ...        ...     ...
# 2549  Pedro Granado Imóveis                     Zona 03  1195000.0  Padrão
# 2550           Lelo Imóveis                     Zona 07   319000.0     NaN
# 2551           Lelo Imóveis              Jardim Guapore  1249000.0     NaN
# 2552           Silvio Iwata                     Zona 06   235000.0     NaN
# 2553           Silvio Iwata  Jardins De Monet Residence   640000.0     NaN
#
#          city state          ref     category    area        lat       long  \
# 0     Maringá    PR       5363.0  Apartamento   55.34 -23.446941 -51.919694
# 1     Maringá    PR      31223.0  Apartamento   48.40 -23.421000 -51.933056
# 2     Maringá    PR      35423.0  Apartamento   66.36 -23.421000 -51.933056
# 3     Maringá    PR      82763.0      Terreno  300.00 -23.459239 -51.981950
# 4     Maringá    PR      48803.0      Terreno  200.00 -23.408781 -51.865269
# ...       ...   ...          ...          ...     ...        ...        ...
# 2549  Maringá    PR        01511  Apartamento  101.00        NaN        NaN
# 2550  Maringá    PR  79900.13356  Apartamento  126.19 -23.407984 -51.940579
# 2551  Maringá    PR  79900.13346         Casa  262.00 -23.441641 -51.955635
# 2552  Maringá    PR          NaN  Apartamento   47.92 -23.428308 -51.971970
# 2553  Maringá    PR          NaN      Terreno  556.46 -23.360507 -52.008474
#
#       num_bedroom  num_bathroom  num_garage  added_date   sold_date  is_sold
# 0             2.0           1.0         NaN  2025-04-15  2025-08-07     True
# 1             1.0           1.0         NaN  2025-04-15         NaN    False
# 2             1.0           1.0         NaN  2025-04-15         NaN    False
# 3             NaN           NaN         NaN  2025-04-15         NaN    False
# 4             NaN           NaN         NaN  2025-04-15         NaN    False
# ...           ...           ...         ...         ...         ...      ...
# 2549          3.0           2.0         1.0  2025-08-07         NaN    False
# 2550          3.0           NaN         1.0  2025-08-07         NaN    False
# 2551          3.0           NaN         2.0  2025-08-07         NaN    False
# 2552          2.0           2.0         1.0  2025-08-07         NaN    False
# 2553          NaN           NaN         NaN  2025-08-07         NaN    False
#
# [2554 rows x 18 columns]

# %%
df = df[pd.to_datetime(df['added_date']) >= pd.to_datetime('01-08-2025', format='%d-%m-%Y')].reset_index(drop=True)
df
# Out:
#                                          property_url                 broker  \
# 0   https://www.pedrogranado.com.br/comprar/maring...  Pedro Granado Imóveis
# 1   https://www.pedrogranado.com.br/comprar/maring...  Pedro Granado Imóveis
# 2   https://www.pedrogranado.com.br/comprar/maring...  Pedro Granado Imóveis
# 3   https://www.pedrogranado.com.br/alugar/maringa...  Pedro Granado Imóveis
# 4   https://www.pedrogranado.com.br/comprar/maring...  Pedro Granado Imóveis
# ..                                                ...                    ...
# 62  https://www.pedrogranado.com.br/comprar/maring...  Pedro Granado Imóveis
# 63  https://www.leloimoveis.com.br/imovel/apartame...           Lelo Imóveis
# 64  https://www.leloimoveis.com.br/imovel/sobrado-...           Lelo Imóveis
# 65  https://www.silvioiwata.com.br/imovel/36200064...           Silvio Iwata
# 66  https://www.silvioiwata.com.br/imovel/36200064...           Silvio Iwata
#
#                                            district      price     type  \
# 0   Conjunto Habitacional Inocente Vila Nova Júnior   259000.0     Casa
# 1                                    Vila Vardelina   275000.0   Padrão
# 2                                   Jardim Brasilia   399000.0  Sobrado
# 3                             Jardim Novo Horizonte        NaN   Padrão
# 4                                           Zona 01  1490000.0   Padrão
# ..                                              ...        ...      ...
# 62                                          Zona 03  1195000.0   Padrão
# 63                                          Zona 07   319000.0      NaN
# 64                                   Jardim Guapore  1249000.0      NaN
# 65                                          Zona 06   235000.0      NaN
# 66                       Jardins De Monet Residence   640000.0      NaN
#
#        city state          ref     category    area        lat       long  \
# 0   Maringá    PR        33983         Casa  259.02        NaN        NaN
# 1   Maringá    PR        64151  Apartamento   51.56        NaN        NaN
# 2   Maringá    PR        79883         Casa  150.00        NaN        NaN
# 3   Maringá    PR        72122  Apartamento   68.73        NaN        NaN
# 4   Maringá    PR        55883  Apartamento  177.99        NaN        NaN
# ..      ...   ...          ...          ...     ...        ...        ...
# 62  Maringá    PR        01511  Apartamento  101.00        NaN        NaN
# 63  Maringá    PR  79900.13356  Apartamento  126.19 -23.407984 -51.940579
# 64  Maringá    PR  79900.13346         Casa  262.00 -23.441641 -51.955635
# 65  Maringá    PR          NaN  Apartamento   47.92 -23.428308 -51.971970
# 66  Maringá    PR          NaN      Terreno  556.46 -23.360507 -52.008474
#
#     num_bedroom  num_bathroom  num_garage  added_date sold_date  is_sold
# 0           3.0           3.0         1.0  2025-08-01       NaN    False
# 1           2.0           1.0         NaN  2025-08-01       NaN    False
# 2           3.0           2.0         1.0  2025-08-01       NaN    False
# 3           3.0           2.0         1.0  2025-08-01       NaN    False
# 4           3.0           4.0         3.0  2025-08-01       NaN    False
# ..          ...           ...         ...         ...       ...      ...
# 62          3.0           2.0         1.0  2025-08-07       NaN    False
# 63          3.0           NaN         1.0  2025-08-07       NaN    False
# 64          3.0           NaN         2.0  2025-08-07       NaN    False
# 65          2.0           2.0         1.0  2025-08-07       NaN    False
# 66          NaN           NaN         NaN  2025-08-07       NaN    False
#
# [67 rows x 18 columns]

# %%
# df = df[df['added_date'] != df['added_date'].min()].reset_index(drop=True)
# df

# %%
df.drop(columns=['property_url','ref','sold_date'], inplace=True)

# %%
df
# Out:
#                    broker                                         district  \
# 0   Pedro Granado Imóveis  Conjunto Habitacional Inocente Vila Nova Júnior
# 1   Pedro Granado Imóveis                                   Vila Vardelina
# 2   Pedro Granado Imóveis                                  Jardim Brasilia
# 3   Pedro Granado Imóveis                            Jardim Novo Horizonte
# 4   Pedro Granado Imóveis                                          Zona 01
# ..                    ...                                              ...
# 62  Pedro Granado Imóveis                                          Zona 03
# 63           Lelo Imóveis                                          Zona 07
# 64           Lelo Imóveis                                   Jardim Guapore
# 65           Silvio Iwata                                          Zona 06
# 66           Silvio Iwata                       Jardins De Monet Residence
#
#         price     type     city state     category    area        lat  \
# 0    259000.0     Casa  Maringá    PR         Casa  259.02        NaN
# 1    275000.0   Padrão  Maringá    PR  Apartamento   51.56        NaN
# 2    399000.0  Sobrado  Maringá    PR         Casa  150.00        NaN
# 3         NaN   Padrão  Maringá    PR  Apartamento   68.73        NaN
# 4   1490000.0   Padrão  Maringá    PR  Apartamento  177.99        NaN
# ..        ...      ...      ...   ...          ...     ...        ...
# 62  1195000.0   Padrão  Maringá    PR  Apartamento  101.00        NaN
# 63   319000.0      NaN  Maringá    PR  Apartamento  126.19 -23.407984
# 64  1249000.0      NaN  Maringá    PR         Casa  262.00 -23.441641
# 65   235000.0      NaN  Maringá    PR  Apartamento   47.92 -23.428308
# 66   640000.0      NaN  Maringá    PR      Terreno  556.46 -23.360507
#
#          long  num_bedroom  num_bathroom  num_garage  added_date  is_sold
# 0         NaN          3.0           3.0         1.0  2025-08-01    False
# 1         NaN          2.0           1.0         NaN  2025-08-01    False
# 2         NaN          3.0           2.0         1.0  2025-08-01    False
# 3         NaN          3.0           2.0         1.0  2025-08-01    False
# 4         NaN          3.0           4.0         3.0  2025-08-01    False
# ..        ...          ...           ...         ...         ...      ...
# 62        NaN          3.0           2.0         1.0  2025-08-07    False
# 63 -51.940579          3.0           NaN         1.0  2025-08-07    False
# 64 -51.955635          3.0           NaN         2.0  2025-08-07    False
# 65 -51.971970          2.0           2.0         1.0  2025-08-07    False
# 66 -52.008474          NaN           NaN         NaN  2025-08-07    False
#
# [67 rows x 15 columns]

# %%
df.to_csv('gold/Properties_gold.csv', index=False, sep=';')
